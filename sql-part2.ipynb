-- %% [markdown]
-- # Exercises
--
-- To get started with the exercises, go ahead and take a look at RideShareDB. This database was created with data from a dataset on [Kaggle](https://www.kaggle.com/fivethirtyeight/uber-pickups-in-new-york-city). The dataset was made using data obtained from the NYC Taxi and Limosine Commission or TLC. TLC tracks this data by base and even rideshare companies such as Uber and Lyft have assigned bases that each pickup must be attributed to. For the exercises, we will be using the `other-FHV-services-jan-july15` and `lyft` tables in RideShareDB. These tables include the data for each pickup attributed to a few other For-Hire Vehicles (FHV) services and Lyft. These tables do not include any data from Uber.
--
-- ## String Functions
--
-- Write a query that returns the last 3 characters of the base name in `other-FHV-services-jan-july15`. Do you see anything that is a common abbreviation at the end of business names?

-- %%
SELECT TOP 10
    Base_Name,
    RIGHT(Base_Name, 3)
AS last_3_char
FROM RideShareDB.dbo.other_FHV_services_jan_aug_2015 ;
-- Out:
-- (10 rows affected)
-- Total execution time: 00:00:00.064
-- <table><tr><th>Base_Name</th><th>last_3_char</th></tr><tr><td>LOVE CORP CAR INC</td><td>INC</td></tr><tr><td>NY ONE CORP CAR INC</td><td>INC</td></tr><tr><td>COMMUNITY CAR SVC CORP</td><td>ORP</td></tr><tr><td>CHARGE AND RIDE INC</td><td>INC</td></tr><tr><td>LIBERTY CAR SERVICE INC.</td><td>NC.</td></tr><tr><td>PROFESSIONAL CAR SERVICE INC</td><td>INC</td></tr><tr><td>PARK WEST EXEC. SERVICES, INC.</td><td>NC.</td></tr><tr><td>YELLOWSTONE TRANSPORTATION INC.</td><td>NC.</td></tr><tr><td>XYZ TWO WAY RADIO</td><td>DIO</td></tr><tr><td>FLEET RADIO DISPATCH CORP.</td><td>RP.</td></tr></table>

-- %% [markdown]
-- The number of trips and the number of pickups are both stored as strings in `other-FHV-services-jan-july15`. This is because the data provided included spaces in some of the numbers. Write a query that returns the location of spaces in both of these columns.

-- %%
SELECT TOP 10
    Number_of_Trips, 
    CHARINDEX( ' ',Number_of_Trips)
AS location_of_space_in_Trips,
    CHARINDEX( ' ',Number_of_Vehicles)
AS location_of_space_in_Vehicles
FROM RideShareDB.dbo.other_FHV_services_jan_aug_2015;
-- Out:
-- (10 rows affected)
-- Total execution time: 00:00:00.047
-- <table><tr><th>Number_of_Trips</th><th>location_of_space_in_Trips</th><th>location_of_space_in_Vehicles</th></tr><tr><td>26 </td><td>3</td><td>3</td></tr><tr><td>45 </td><td>3</td><td>3</td></tr><tr><td>731 </td><td>4</td><td>3</td></tr><tr><td>10 </td><td>3</td><td>2</td></tr><tr><td>814 </td><td>4</td><td>3</td></tr><tr><td>220 </td><td>4</td><td>3</td></tr><tr><td>36 </td><td>3</td><td>3</td></tr><tr><td> 1,137 </td><td>1</td><td>4</td></tr><tr><td>236 </td><td>4</td><td>4</td></tr><tr><td>47 </td><td>3</td><td>3</td></tr></table>

-- %% [markdown]
-- ## Date Functions
--
-- For ``other-FHV-services-jan-july15``, display the name of month of the pickup date and order in descending order. Is the result of this query what you expected?

-- %%
SELECT 
    Pick_Up_Date, 
    DATENAME(month, Pick_Up_Date)
AS Name_month
FROM RideShareDB.dbo.other_FHV_services_jan_aug_2015
ORDER BY Name_month DESC;
-- Out:
-- (26181 rows affected)
-- Displaying Top 5000 rows.
-- Total execution time: 00:00:00.543
-- <table><tr><th>Pick_Up_Date</th><th>Name_month</th></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td><td>May</td></tr><tr><td>2015-05-01</td>< ...

-- %% [markdown]
-- Using `other-FHV-services-jan-july15`, write a query that returns the day number of the pickup date and month name and orders it in ascending order by day number.

-- %%
SELECT 
    Pick_Up_Date, 
    DAY(Pick_Up_Date) AS day_number,
    DATENAME(month, Pick_Up_Date) AS Pickup_Month_name
FROM RideShareDB.dbo.other_FHV_services_jan_aug_2015
ORDER BY day_number;
-- Out:
-- (26181 rows affected)
-- Displaying Top 5000 rows.
-- Total execution time: 00:00:00.580
-- <table><tr><th>Pick_Up_Date</th><th>day_number</th><th>Pickup_Month_name</th></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01</td><td>1</td><td>April</td></tr><tr><td>2015-04-01 ...

-- %% [markdown]
-- ## Aggregate Functions
--
-- Write a query that returns the most easterly Lyft pickup.

-- %%
SELECT MAX(start_lng) AS East
FROM RideShareDB.dbo.lyft;
-- Out:
-- Warning: Null value is eliminated by an aggregate or other SET operation.
-- (1 row affected)
-- Total execution time: 00:00:00.080
-- <table><tr><th>East</th></tr><tr><td>-73.72315</td></tr></table>

-- %% [markdown]
-- Write a query the returns the most northerly Lyft pickup.

-- %%
SELECT MAX(start_lat) AS North
FROM RideShareDB.dbo.lyft;
-- Out:
-- Warning: Null value is eliminated by an aggregate or other SET operation.
-- (1 row affected)
-- Total execution time: 00:00:00.077
-- <table><tr><th>North</th></tr><tr><td>40.93562</td></tr></table>

-- %% [markdown]
-- Using ``other-FHV-services-jan-july15``, write a query that connects the the base number and the base name in a string that uses the following format: base\_number: base\_name.

-- %%
SELECT CONCAT_WS(': ', Base_Number, Base_Name) As "Base Number: Base Name"
FROM RideShareDB.dbo.other_FHV_services_jan_aug_2015;
-- Out:
-- (26181 rows affected)
-- Displaying Top 5000 rows.
-- Total execution time: 00:00:00.869
-- <table><tr><th>Base Number: Base Name</th></tr><tr><td>B00013: LOVE CORP CAR INC</td></tr><tr><td>B00014: NY ONE CORP CAR INC</td></tr><tr><td>B00029: COMMUNITY CAR SVC CORP</td></tr><tr><td>B00053: CHARGE AND RIDE INC</td></tr><tr><td>B00095: LIBERTY CAR SERVICE INC.</td></tr><tr><td>B00221: PROFESSIONAL CAR SERVICE INC</td></tr><tr><td>B00227: PARK WEST EXEC. SERVICES, INC.</td></tr><tr><td>B00248: YELLOWSTONE TRANSPORTATION INC.</td></tr><tr><td>B00254: XYZ TWO WAY RADIO</td></tr><tr><td>B00280: FLEET RADIO DISPATCH CORP.</td></tr><tr><td>B00310: WATSON CAR SERVICE INC.</td></tr><tr><td>B00381: BELL RADIO INC</td></tr><tr><td>B00412: NYC 2 WAY INTERNATIONAL LTD</td></tr><tr><td>B00457: PREMIUM BRONX CORP</td></tr><tr><td>B00477: INTA-BORO ACRES INC</td></tr><tr><td>B00552: HINO-MARU ENTERPRISES INC.</td></tr><tr><td>B00623: MANHATTAN INT'L LIMO NETWORK LLC</td></tr><tr><td>B00837: CAREY LIMO N Y INC</td></tr><tr><td>B00887: DIAL 7 CAR &amp; LIMOUSINE SERVICE INC.</td></tr><tr><td>B00919: HARLEM CARS INC.</td></tr><tr><td>B00948: 510 CAR SERVICE CORP</td></tr><tr><td>B01066: DOMINICANA RAD DISP INC</td></tr><tr><td>B01083: BROAD DYCKMAN C/S INC</td></tr><tr><td>B01087: ELITE LIMO PLUS INC</td></tr><tr><td>B01148: EVELYN CAR SERVICE INC</td></tr><tr><td>B01197: TEL-A-CAR OF NEW YORK, LLC</td></tr><tr><td>B01282: NEW LOTS C/S INC</td></tr><tr><td>B01285: UNION RADIO DISPATCH INC</td></tr><tr><td>B01300: KENNEDY RAD DISP INC</td></tr><tr><td>B01312: BROOKLYN RAD DISP INC</td></tr><tr><td>B01313: JOY CAR SERVICES INC.</td></tr><tr><td>B01315: V.I.T. CAR SERVICE, INC.</td></tr><tr><td>B01341: A NEW DAY RAD DISP INC</td></tr><tr><td>b01346: ARECIBO C/S INC</td></tr><tr><td>B01367    : ROYAL DISPATCH SERVICES, INC.</td></tr><tr><td>B01386: FENIX CAR SVCE CORP</td></tr><tr><td>B01522: STM ENTERPRISES,INC</td></tr><tr><td>B01651: U.P.S. RADIO DISPATCH CORP.</td></tr><tr><td>B01777: PREMIUM RADIO DISP &amp; MULTI SVC</td></tr><tr><td>B01848: GRAND LIMO &amp; CAR SERVICE INC.</td></tr><tr><td>B01877: U.S.A. LIMO. INC.</td></tr><tr><td>B01899: ALLSTATE PRIVATE CAR &amp; LIMO,INC</td></tr><tr><td>B01984: NY 88 EXPRESS CORP.</td></tr><tr><td>B01990: SUK INCORPORATED</td></tr><tr><td>B02003: AVALON CORPORATE CAR,INC.</td></tr><tr><td>B02022: GOLD SEAL CAR &amp; LIMO INC.</td></tr><tr><td>B02096: CET GROUP, INC</td></tr><tr><td>B02107: APOLLO RADIO DISPATCH INC.</td></tr><tr><td>B02120: HARRISON GLOBAL LLC</td></tr><tr><td>B02147: MITA LIMOUSINE, INC.</td></tr><tr><td>B02285: VALERA GLOBAL, INC.</td></tr><tr><td>B02475: ECKFORD LITE CAR &amp; LIMO INC.</td></tr><tr><td>B02513: INTABORO PREMIERE TRANSP. SVCS., INC.</td></tr><tr><td>B02566: GSL LIMOUSINES CORP.</td></tr><tr><td>B02569: GOGREENRIDE INC.</td></tr><tr><td>B02653: NEW COLLEGE CAR SVCE INC</td></tr><tr><td>B02715: GROUNDANYWHERE LLC</td></tr><tr><td>B00013: LOVE CORP CAR INC</td></tr><tr><td>B00014: NY ONE CORP CAR INC</td></tr><tr><td>B00029: COMMUNITY CAR SVC CORP</td></tr><tr><td>B00053: CHARGE AND RIDE INC</td></tr><tr><td>B00095: LIBERTY CAR SERVICE INC.</td></tr><tr><td>B00221: PROFESSIONAL CAR SERVICE INC</td></tr><tr><td>B00227: PARK WEST EXEC. SERVICES, INC.</td></tr><tr><td>B00248: YELLOWSTONE TRANSPORTATION INC.</td></tr><tr><td>B00254: XYZ TWO WAY RADIO</td></tr><tr><td>B00280: FLEET RADIO DISPATCH CORP.</td></tr><tr><td>B00310: WATSON CAR SERVICE INC.</td></tr><tr><td>B00381: BELL RADIO INC</td></tr><tr><td>B00412: NYC 2 WAY INTERNATIONAL LTD</td></tr><tr><td>B00457: PREMIUM BRONX CORP</td></tr><tr><td>B00477: INTA-BORO ACRES INC</td></tr><tr><td>B00552: HINO-MARU ENTERPRISES INC.</td></tr><tr><td>B00623: MANHATTAN INT'L LIMO NETWORK LLC</td></tr><tr><td>B00837: CAREY LIMO N Y INC</td></tr><tr><td>B00887: DIAL 7 CAR &amp; LIMOUSINE SERVICE INC.</td></tr><tr><td>B00919: HARLEM CARS INC.</td></tr><tr><td>B00948: 510 CAR SERVICE CORP</td></tr><tr><td>B01066: DOMINICANA RAD DISP INC</td></tr><tr><td>B01083: BROAD DYCKMAN C/S INC</td></tr><tr><td>B01087: ELITE LIMO PLUS IN ...
